# %% [markdown]
# # L02: International quiet days

# %%
# import libraries we will be using
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get what are the International Quiet Days (IQD) for a specific month from the web: http://wdc.kugi.kyoto-u.ac.jp/qddays/index.html
# ### <span style="color:green">Check that IQDs for March 2015 are the following: </span>

# %%
# IQDs for March 2013
qs=['8','7','26','25','13']

# %% [markdown]
# ## Q01: ¿Did you have to change any of the days?

# %% [markdown]
# ### A01:

# %% [markdown]
# ## Information about the observatories used to create Dst index can be obtained from Kyoto WDC: http://wdc.kugi.kyoto-u.ac.jp/dstdir/dst2/onDstindex.html
# ### <span style="color:green">Check that the code used for the stations are the following: </span>

# %%
# observatories used for Dst index
obs=['her','hon','kak','sjg']

# %% [markdown]
# ## Q02: ¿Are they correct?

# %% [markdown]
# ### A02:

# %%
# create the filenames for the four observatories and the five IQDs
for qi in qs:
    for o in obs:
        folder='i4s_geomag_data/'
        filename=folder + o + '201303-' + qi + 'dmin.min'
        print(filename)
# Out:
# i4s_geomag_data/her201303-8dmin.min
# i4s_geomag_data/hon201303-8dmin.min
# i4s_geomag_data/kak201303-8dmin.min
# i4s_geomag_data/sjg201303-8dmin.min
# i4s_geomag_data/her201303-7dmin.min
# i4s_geomag_data/hon201303-7dmin.min
# i4s_geomag_data/kak201303-7dmin.min
# i4s_geomag_data/sjg201303-7dmin.min
# i4s_geomag_data/her201303-26dmin.min
# i4s_geomag_data/hon201303-26dmin.min
# i4s_geomag_data/kak201303-26dmin.min
# i4s_geomag_data/sjg201303-26dmin.min
# i4s_geomag_data/her201303-25dmin.min
# i4s_geomag_data/hon201303-25dmin.min
# i4s_geomag_data/kak201303-25dmin.min
# i4s_geomag_data/sjg201303-25dmin.min
# i4s_geomag_data/her201303-13dmin.min
# i4s_geomag_data/hon201303-13dmin.min
# i4s_geomag_data/kak201303-13dmin.min
# i4s_geomag_data/sjg201303-13dmin.min

# %% [markdown]
# ## Q03: Do you think we can read the files under the folder dst_stations with these names?, would you change something to make it work?

# %% [markdown]
# ### A03:

# %%
filename='i4s_geomag_data/her20130308dmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=26,names=names, colspecs=colspecs)
plt.plot(df.c1);

filename='i4s_geomag_data/her20130307dmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=26,names=names, colspecs=colspecs)
plt.plot(df.c1);

# %% [markdown]
# ## Q04: What does the figure above shows?, number of data points, source observatories, shape of the curves ... any other observation?

# %% [markdown]
# ### A04:

# %%
filename='i4s_geomag_data/her20130307dmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=26,names=names, colspecs=colspecs)
plt.plot(df.c1)

filename='i4s_geomag_data/her20130326dmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=26,names=names, colspecs=colspecs)
plt.plot(df.c1)

# %% [markdown]
# ## Q05: Say something about the differences with the previous figure and what do you think the reason is?

# %% [markdown]
# ### A05:

# %%
filename='i4s_geomag_data/kak20130308dmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=25,names=names, colspecs=colspecs)
plt.plot(df.c1)


filename='i4s_geomag_data/sjg20130308dmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=26,names=names, colspecs=colspecs)
plt.plot(df.c1)

# %% [markdown]
# ## Q06: What happens in this plot?, what is the problem?

# %% [markdown]
# ### A06:

# %% [markdown]
# ## Q07: Any idea on how to show data from two different observatories superposed on the same plot?, you can write code and test it

# %% [markdown]
# ### A07:
