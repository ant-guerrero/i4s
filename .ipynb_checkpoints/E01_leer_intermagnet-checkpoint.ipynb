# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime

# trabajaremos con el fichero siguiente:
    # observatorio: hermanus (HER)
    # día: 10-03-2015
    # tipo: quasi-definitive (q)
    # resolución: minutos (min)
filename='dst_stations/2015-03/her/her20150310qmin.min'

# %%
# leemos el fichero
names=['datetime','doy','c1','c2','c3','c4']
colspecs=[(0,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=20,names=names, colspecs=colspecs)
# Out:
# 1440
# 1440

# %%
# obtener el formato de las componentes
f=open(filename)
lines=f.readlines()
componentes=lines[7].split()[1]

print(componentes)
# Out:
# HDZF

# %%
# obtener la latitud y la longitud geográfica del observatorio
f=open(filename)
lines=f.readlines()
latitud=lines[4].split()[2]
longitud=lines[5].split()[2]

print(latitud, longitud)
# Out:
# -34.400 19.200

# %%
# creamos la figura
fig, ax = plt.subplots()
ax.plot(tiempo,datos)

# modificamos los formatos de los ejes
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d %H:%M"))
ax.xaxis.set_minor_formatter(mdates.DateFormatter("%Y-%m-%d %H:%M"))
_ = plt.xticks(rotation=90)
